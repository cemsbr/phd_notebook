# %%
from inc.notebook003 import *

# %%
analyze_all_logs()
# Out:
# wikipedia/target/app-20150606192726-0000 has 354 blocks, but 362 successful tasks.
# wikipedia/target/app-20150606221910-0000 has 346 blocks, but 362 successful tasks.
# wikipedia/target/app-20150606162439-0000 has 358 blocks, but 362 successful tasks.
# wikipedia/target/app-20150606151354-0000 has 358 blocks, but 362 successful tasks.
# wikipedia/target/app-20150606163447-0000 has 358 blocks, but 362 successful tasks.
# wikipedia/target/app-20150606152906-0000 has 358 blocks, but 362 successful tasks.
# wikipedia/target/app-20150606213612-0000 has 346 blocks, but 362 successful tasks.
# wikipedia/target/app-20150607031932-0000 has 296 blocks, but 362 successful tasks.
# wikipedia/target/app-20150606211138-0000 has 346 blocks, but 362 successful tasks.
# wikipedia/target/app-20150607030047-0000 has 297 blocks, but 362 successful tasks.
# wikipedia/target/app-20150607031404-0000 has 298 blocks, but 362 successful tasks.
# ...
