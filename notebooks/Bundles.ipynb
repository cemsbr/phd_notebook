# %%
# %%time
from lib.bundler import Bundler


Bundler.set_bundles_root('..', 'bundles')
csv_file = Bundler.get_file('outliers_detection', 'outliers_detected.csv')
# Out:
# CPU times: user 26.7 ms, sys: 0 ns, total: 26.7 ms
# Wall time: 25.7 ms

# %%
import pandas as pd
from lib.outlier import Outlier
from inc import helper


df = pd.read_csv(csv_file)
#outlier = Outlier(df.drop([df.application == 'wikipedia'], col='duration_ms')
#outlier.get_overview()
overview = helper.get_outlier_overview(df)
idx = pd.IndexSlice
overview
# TODO remove access to disk
# Out:
#                                            mean (sec)  samples  outliers  \
# application set       input       workers
# hbkmeans    profiling 32000       1         18.969400       10         0
#                                   2         17.716875       10         2
#                                   3         17.323875       10         2
#                                   4         18.876400       10         0
#                                   5         19.902111       10         1
#                                   6         20.970800       10         0
#                                   7         21.897600       10         0
#                                   8         23.255889       10         1
#                       64000       1         19.082400       10         0
#                                   2         18.596000       10         0
#                                   3         17.923500       10         0
# ...

# %%
pd.read_csv?
